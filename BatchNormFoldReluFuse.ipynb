# %% [markdown]
# ## QDenseBatchnorm Test Notebook
# ***
# QDenseBatchnorm should fold quantized Dense parameters into the the Batchnorm layer to reduce the LUT (look up table) utilization at HLS and Vivado FPGA Implementation time

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import common as com
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.models
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Activation
from tensorflow.keras.regularizers import l1
from qkeras.qlayers import QDense, QActivation
from qkeras import QDenseBatchnorm
from qkeras.quantizers import quantized_bits, quantized_relu
import hls4ml
from plot_roc import plot_roc
from tqdm.notebook import tqdm

os.environ['PATH'] = '/tools/Xilinx/Vivado/2019.1/bin:' + os.environ['PATH']
# Out:
# /opt/conda/envs/qdense_batchnorm/lib/python3.7/site-packages/hls4ml/converters/__init__.py:16: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!")

# %%
def print_dict(d, indent=0):
    align = 20
    for key, value in d.items():
        print('  ' * indent + str(key), end='')
        if isinstance(value, dict):
            print()
            print_dict(value, indent+1)
        else:
            print(':' + ' ' * (20 - len(key) - 2 * indent) + str(value))

# %% [markdown]
# ### Load model and test data

# %%
import keras_model
#83.3 accuracy
#model = keras_model.load_model('model/model_config/fold_bn_run_1/fold_bn_96input_depth3_16_6/model_ToyCar.h5')
#output_dir = 'hls/fold_bn_96input_depth3_16_6'
#hls4ml_config = 'model/model_config/fold_bn_run_1/fold_bn_96input_depth3_16_6/hls4ml_config.yml'


#83.1 accuracy
#model = keras_model.load_model('model/model_config/fold_bn_64input_depth2_12_6/model_ToyCar.h5')
#output_dir = 'hls/fold_bn_64input_depth2_12_6_relu_merge'
#hls4ml_config = 'model/model_config/fold_bn_64input_depth2_12_6/hls4ml_config.yml'

#82.7 accuracy
#model = keras_model.load_model('model/model_config/fold_bn_run_1/fold_bn_96input_depth2_14_6/model_ToyCar.h5')
#output_dir = 'hls/fold_bn_96input_depth2_14_6'
#hls4ml_config = 'model/model_config/fold_bn_96input_depth2_14_6/hls4ml_config.yml'

#82.6 accuracy
model = keras_model.load_model('model/model_config/fold_bn_run_1/fold_bn_128input_depth2_16_6/model_ToyCar.h5')
output_dir = 'hls/delete_me'
hls4ml_config = 'model/model_config/fold_bn_run_1/fold_bn_128input_depth2_16_6/hls4ml_config.yml'

#82.5 accuracy
#model = keras_model.load_model('model/model_config/fold_bn_run_1/fold_bn_64input_depth3_12_6/model_ToyCar.h5')
#output_dir = 'hls/fold_bn_64input_depth3_12_6'

model.summary()
# if train_data available, load processed data in local directory without reprocessing wav files --saves time--
X_npy_dir = 'test_data/anomaly_detection/evaluation/downsampled_128_5_to_32_4_skip_method.npy'
y_npy_dir = 'test_data/anomaly_detection/evaluation/downsampled_128_5_to_32_4_ground_truths_skip_method.npy'
X = np.load(X_npy_dir, allow_pickle=1)
# Out:
# 2022-02-07 18:17:14.172230: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 18:17:14.182306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 18:17:14.183086: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 18:17:14.184781: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-07 18:17:14.186136: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 18:17:14.186979: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 18:17:14.187619: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 18:17:14.799903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 18:17:14.800717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 18:17:14.801392: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 18:17:14.801991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14634 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128)]             0
#
#  q_dense_batchnorm (QDenseBa  (None, 64)               8513
#  tchnorm)
#
#  q_activation (QActivation)  (None, 64)                0
#
#  q_dense_batchnorm_1 (QDense  (None, 64)               4417
#  Batchnorm)
#
#  q_activation_1 (QActivation  (None, 64)               0
#  )
#
#  q_dense_batchnorm_2 (QDense  (None, 8)                553
#  Batchnorm)
#
#  q_activation_2 (QActivation  (None, 8)                0
#  )
#
#  q_dense_batchnorm_3 (QDense  (None, 64)               833
#  Batchnorm)
#
#  q_activation_3 (QActivation  (None, 64)               0
#  )
#
#  q_dense_batchnorm_4 (QDense  (None, 64)               4417
#  Batchnorm)
#
#  q_activation_4 (QActivation  (None, 64)               0
#  )
#
#  q_dense (QDense)            (None, 128)               8320
#
# =================================================================
# Total params: 27,053
# Trainable params: 26,520
# Non-trainable params: 533
# _________________________________________________________________

# %% [markdown]
# ### HLS4ML Translation of reference model

# %%
hls4ml.model.optimizer.OutputRoundingSaturationMode.layers = ['Activation']
hls4ml.model.optimizer.OutputRoundingSaturationMode.rounding_mode = 'AP_RND'
hls4ml.model.optimizer.OutputRoundingSaturationMode.saturation_mode = 'AP_SAT'
hls_config = com.yaml_load(hls4ml_config)
hls_config['Model'] = {}
#hls_config = hls4ml.utils.config_from_keras_model(model, granularity='name')
hls_config['Model']['ReuseFactor'] = 16384
hls_config['Model']['Strategy'] = 'Resource'
hls_config['Model']['Precision'] = 'ap_fixed<16,8>'
hls_config['LayerName']['input_1']['Precision'] = 'ap_fixed<8,8>'
#for layer in hls_config['LayerName'].keys():
#    hls_config['LayerName'][layer]['Trace'] = True
#    hls_config['LayerName'][layer]['ReuseFactor'] = 16384 #huge number, hls4ml will clip to #inputs*layer_width
#    hls_config['LayerName'][layer]['accum_t'] = 'ap_fixed<16,8>'
#hls_config['LayerName']['q_dense']['accum_t'] = 'ap_fixed<16,8>'
    
cfg = hls4ml.converters.create_config(
            backend='VivadoAccelerator',
            part='xc7z020clg400-1',
            clock_period=10,
            io_type='io_stream')

cfg['HLSConfig'] = hls_config
cfg['InputData'] = 'test_data/anomaly_detection/test_bench/downsampled_128_5_to_32_2_skip_method.npy'
cfg['OutputPredictions'] = 'test_data/anomaly_detection/test_bench/downsampled_128_5_to_32_2_ground_truths_skip_method.npy'
cfg['KerasModel'] = model
cfg['OutputDir'] = output_dir

print("-----------------------------------")
print_dict(cfg)
print("-----------------------------------")

hls_model = hls4ml.converters.keras_to_hls(cfg)

hls_model.compile()
# Out:
# -----------------------------------
# OutputDir:           hls/delete_me
# ProjectName:         myproject
# Backend:             VivadoAccelerator
# XilinxPart:          xc7z020clg400-1
# Board:               pynq-z2
# ClockPeriod:         10
# IOType:              io_stream
# HLSConfig
#   LayerName
#     input_1
#       Precision:     ap_fixed<8,8>
#       ReuseFactor:   16384
#       Trace:         True
#       accum_t:       ap_fixed<16,8>
#     q_activation
#       Precision
#         result:      ap_ufixed<5,5>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#     q_activation_1
#       Precision
#         result:      ap_ufixed<5,5>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#     q_activation_2
#       Precision
#         result:      ap_ufixed<5,5>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#     q_activation_3
#       Precision
#         result:      ap_ufixed<5,5>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#     q_activation_4
#       Precision
#         result:      ap_ufixed<5,5>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#     q_dense
#       Precision
#         bias:        ap_fixed<6,2>
#         weight:      ap_fixed<10,2>
#       ReuseFactor:   16384
#       Trace:         True
#       accum_t:       ap_fixed<16,8>
#     q_dense_linear
#       Precision
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#     q_dense_batchnorm
#       Precision
#         bias:        ap_fixed<17,7>
#         weight:      ap_fixed<17,7>
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#       accum_t:       ap_fixed<16,8>
#     q_dense_batchnorm_linear
#       Precision
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#     q_dense_batchnorm_1
#       Precision
#         bias:        ap_fixed<15,5>
#         weight:      ap_fixed<15,5>
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#       accum_t:       ap_fixed<16,8>
#     q_dense_batchnorm_1_linear
#       Precision
#         bias:        ap_fixed<16,8>
#         weight:      ap_fixed<16,8>
#     q_dense_batchnorm_2
#       Precision
#         bias:        ap_fixed<15,5>
#         weight:      ap_fixed<15,5>
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#       accum_t:       ap_fixed<16,8>
#     q_dense_batchnorm_2_linear
#       Precision
#         bias:        ap_fixed<16,8>
#         weight:      ap_fixed<16,8>
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#     q_dense_batchnorm_3
#       Precision
#         bias:        ap_fixed<16,6>
#         weight:      ap_fixed<16,6>
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#       accum_t:       ap_fixed<16,8>
#     q_dense_batchnorm_3_linear
#       Precision
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#     q_dense_batchnorm_4
#       Precision
#         bias:        ap_fixed<15,5>
#         weight:      ap_fixed<15,5>
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#       ReuseFactor:   16384
#       Trace:         True
#       accum_t:       ap_fixed<16,8>
#     q_dense_batchnorm_4_linear
#       Precision
#         result:      ap_fixed<16,8>
#         default:     ap_fixed<16,8>
#   Model
#     ReuseFactor:     16384
#     Strategy:        Resource
#     Precision:       ap_fixed<16,8>
# AcceleratorConfig
#   Interface:         axi_stream
#   Driver:            python
#   Precision
#     Input:           float
#     Output:          float
# InputData:           test_data/anomaly_detection/test_bench/downsampled_128_5_to_32_2_skip_method.npy
# OutputPredictions:   test_data/anomaly_detection/test_bench/downsampled_128_5_to_32_2_ground_truths_skip_method.npy
# KerasModel:          <keras.engine.functional.Functional object at 0x7f8750354990>
# -----------------------------------
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 128]], output shape: [None, 128]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm, layer type: QDenseBatchnorm, input shapes: [[None, 128]], output shape: [None, 64]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm_1, layer type: QDenseBatchnorm, input shapes: [[None, 64]], output shape: [None, 64]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm_2, layer type: QDenseBatchnorm, input shapes: [[None, 64]], output shape: [None, 8]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 8]], output shape: [None, 8]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm_3, layer type: QDenseBatchnorm, input shapes: [[None, 8]], output shape: [None, 64]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm_4, layer type: QDenseBatchnorm, input shapes: [[None, 64]], output shape: [None, 64]
# Layer name: q_activation_4, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# Layer name: q_dense, layer type: QDense, input shapes: [[None, 64]], output shape: [None, 128]
# Creating HLS model
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "input_1" (Input)
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm". Using ReuseFactor=4096 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm_1" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm_1". Using ReuseFactor=4096 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm_2" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm_2". Using ReuseFactor=64 instead. Valid ReuseFactor(s): 2,4,8,16,32,64.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm_3" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm_3". Using ReuseFactor=4096 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm_4" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm_4". Using ReuseFactor=4096 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense" (Dense)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense". Using ReuseFactor=8192 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096,8192.
# Writing HLS project
# Done

# %%
# %matplotlib inline
_= hls4ml.model.profiling.numerical(model=model, hls_model=hls_model,X=X[1][0])
# Run tracing on a portion of the test set for the hls model (fixed-point precision) 
hls4ml_pred, hls4ml_trace = hls_model.trace(np.ascontiguousarray(X[1][0][0]))

# Run tracing on a portion of the test set for the Keras model (floating-point precision)
keras_trace = hls4ml.model.profiling.get_ymodel_keras(model, X[1][0])
# Out:
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 128]], output shape: [None, 128]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm, layer type: QDenseBatchnorm, input shapes: [[None, 128]], output shape: [None, 64]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm_1, layer type: QDenseBatchnorm, input shapes: [[None, 64]], output shape: [None, 64]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm_2, layer type: QDenseBatchnorm, input shapes: [[None, 64]], output shape: [None, 8]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 8]], output shape: [None, 8]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm_3, layer type: QDenseBatchnorm, input shapes: [[None, 8]], output shape: [None, 64]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# QDenseBatchnorm
# Layer name: q_dense_batchnorm_4, layer type: QDenseBatchnorm, input shapes: [[None, 64]], output shape: [None, 64]
# Layer name: q_activation_4, layer type: Activation, input shapes: [[None, 64]], output shape: [None, 64]
# Layer name: q_dense, layer type: QDense, input shapes: [[None, 64]], output shape: [None, 128]
# Creating HLS model
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "input_1" (Input)
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm". Using ReuseFactor=4096 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm_1" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm_1". Using ReuseFactor=4096 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm_2" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm_2". Using ReuseFactor=64 instead. Valid ReuseFactor(s): 2,4,8,16,32,64.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm_3" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm_3". Using ReuseFactor=4096 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense_batchnorm_4" (DenseBatchnorm)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense_batchnorm_4". Using ReuseFactor=4096 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096.
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "q_dense" (Dense)
# WARNING: Invalid ReuseFactor=16384 with "Resource" strategy in layer "q_dense". Using ReuseFactor=8192 instead. Valid ReuseFactor(s): 2,4,8,16,32,64,128,256,512,1024,2048,4096,8192.
# Profiling weights (before optimization)
# Profiling weights (final / after optimization)
# Profiling activations (before optimization)
#    input_1
#    q_dense_batchnorm
#    q_activation
#    q_dense_batchnorm_1
#    q_activation_1
#    q_dense_batchnorm_2
#    q_activation_2
#    q_dense_batchnorm_3
#    q_activation_3
#    q_dense_batchnorm_4
#    q_activation_4
#    q_dense
# Profiling activations (final / after optimization)
# Recompiling myproject with tracing
# Writing HLS project
# Done
#    q_dense_batchnorm
#    q_activation
#    q_dense_batchnorm_1
#    q_activation_1
#    q_dense_batchnorm_2
#    q_activation_2
#    q_dense_batchnorm_3
#    q_activation_3
#    q_dense_batchnorm_4
#    q_activation_4
#    q_dense
# Recompiling myproject with tracing
# Writing HLS project
# Done
# Processing input_1 in Keras model...
# Processing q_dense_batchnorm in Keras model...
# Processing q_activation in Keras model...
# Processing q_dense_batchnorm_1 in Keras model...
# Processing q_activation_1 in Keras model...
# Processing q_dense_batchnorm_2 in Keras model...
# Processing q_activation_2 in Keras model...
# Processing q_dense_batchnorm_3 in Keras model...
# Processing q_activation_3 in Keras model...
# Processing q_dense_batchnorm_4 in Keras model...
# Processing q_activation_4 in Keras model...
# Processing q_dense in Keras model...
# Done taking outputs for Keras model.

# %%
# %matplotlib inline
for key in hls4ml_trace:
    plt.figure()
    plt.scatter(keras_trace[key][0], hls4ml_trace[key][0], color='black')
    plt.plot(np.linspace(np.min(keras_trace[key][0]),np.max(keras_trace[key][0]), 10), 
             np.linspace(np.min(keras_trace[key][0]),np.max(keras_trace[key][0]), 10), label='keras_range')
    plt.plot(np.linspace(np.min(hls4ml_trace[key][0]),np.max(hls4ml_trace[key][0]), 10), 
             np.linspace(np.min(hls4ml_trace[key][0]),np.max(hls4ml_trace[key][0]), 10), label='hls4ml_range')
    plt.title(key)
    plt.xlabel('keras output')
    plt.ylabel('hls4ml output')
    plt.legend()
    plt.show()

# %%
# %matplotlib inline
plot_roc(model, hls_model, X_npy_dir, y_npy_dir,data_split_factor=1)

# %% [markdown]
# ### Synthesize Design

# %%
# %%time
hls_model.build(reset=False, csim=True, cosim=True, validation=True, synth=True, vsynth=True, export=True)

# %%
# %%time
hls4ml.templates.VivadoAcceleratorBackend.make_bitfile(hls_model)
